# %% [markdown]
# # LAB 06: Aggregate Analysis
# ## Bicycle Share Dataset
# ## Keith Eckert 3-26-18

# %%
import pandas
import numpy
from datetime import date

# %%
station_data = pandas.read_csv('./cycle-dataset/station.csv')
trip_data = pandas.read_csv('./cycle-dataset/trip.csv', skiprows=[50793])

weather_data = pandas.read_csv('./cycle-dataset/weather.csv')
# station_data.head()
# weather_data.head()

# %%
# trip_data.head()

# %% [markdown]
# ### i) What is the average trip duration for a borrowed bicycle?

# %%
duration_avg = round(trip_data['tripduration'].mean(), 2)
print('average trip duration: {} seconds'.format(duration_avg))
# Out:
# average trip duration: 1178.3 seconds

# %% [markdown]
# ### ii) What's the most common age of a bicycle-sharer?

# %%
trip_data['starttime'] = pandas.to_datetime(trip_data['starttime'], errors='coerce')
trip_data['age'] = trip_data['starttime'].dt.year - trip_data['birthyear']
common_age = trip_data['age'].mode()
print('most common rider age: {} years old.'.format(common_age))
# trip_data.head()
# Out:
# most common rider age: 0    28.0
# dtype: float64 years old.

# %% [markdown]
# ### iii) Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
# weather_data.head()

# %%
weather_data['parsedate'] = pandas.to_datetime(weather_data['Date'], errors='coerce')
weather_data['month'] = weather_data['parsedate'].dt.month
rain_by_month = weather_data[['month', 'Precipitation_In']].groupby(weather_data.month)
sum_prcp = pandas.DataFrame(rain_by_month['Precipitation_In'].sum())
sum_prcp
# Out:
#        Precipitation_In
# month
# 1                  8.90
# 2                  9.60
# 3                  9.73
# 4                  3.08
# 5                  0.77
# 6                  1.83
# 7                  0.75
# 8                  1.13
# 9                  1.23
# 10                 9.45
# 11                11.27
# 12                14.65

# %% [markdown]
# ### iv) What’s the average number of bikes at a given bike station?

# %%
# station_data.head()

# %%
avg_bikes = station_data[['name', 'current_dockcount']].groupby(station_data.name)
avg_bikes.head()
# Out:
#                                                  name  current_dockcount
# 0                                  3rd Ave & Broad St                 18
# 1                                   2nd Ave & Vine St                 16
# 2                              6th Ave & Blanchard St                 16
# 3                              2nd Ave & Blanchard St                 14
# 4                                  7th Ave & Union St                 20
# 5                                  Union St & 4th Ave                 18
# 6                                 1st Ave & Marion St                 20
# 7                                 2nd Ave & Spring St                 18
# 8                      City Hall / 4th Ave & James St                 20
# 9                                   2nd Ave & Pine St                 18
# 10                            12th Ave & E Yesler Way                  0
# 11                           Summit Ave & E Denny Way                 16
# ...

# %% [markdown]
# ### v) When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %%
station_data['after_mod_count'] = station_data['install_dockcount'] - station_data['current_dockcount']
print('average increase after mod: {} bikes'.format(round(station_data['after_mod_count'].mean(), 2)))
# Out:
# average increase after mod: 1.07 bikes

# %% [markdown]
# ### vi) Come up with 3 more questions that can be answered with this data set.

# %%
weather_data.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity  ...    Max_Visibility_Miles  \
# 0             68            46  ...                      10
# ...

# %%
weather_data.describe()
# Out:
#        Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# count         689.000000          688.000000        689.000000
# mean           64.027576           56.584302         49.454282
# std            12.427843           10.408058          9.451437
# min            39.000000           33.000000         23.000000
# 25%            55.000000           48.000000         43.000000
# 50%            63.000000           56.000000         50.000000
# 75%            73.000000           65.000000         57.000000
# max            98.000000           83.000000         70.000000
#
#        Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# count       689.000000       689.000000      689.000000    689.000000
# mean         48.571843        45.021771       40.873730     84.541364
# std           7.501230         7.914025        8.854608      9.718948
# min          10.000000         4.000000        1.000000     40.000000
# ...

# %% [markdown]
# ### Find Maximum Temperature recorded

# %%
weather_data['Max_Temperature_F'].max()
# Out:
# 98
